# %%
import json
from azure.identity import DefaultAzureCredential
from azure.search.documents.indexes import SearchIndexClient

service_endpoint = "https://ai-search-taeyok.search.windows.net"
credential = DefaultAzureCredential()
client = SearchIndexClient(endpoint = service_endpoint, credential = credential)

# List existing indexes
indexes = client.list_indexes()

for index in indexes:
   index_dict = index.as_dict()
   print(json.dumps(index_dict, indent = 2))
# Out:
# {
#   "name": "hotels-sample-index",
#   "fields": [
#     {
#       "name": "HotelId",
#       "type": "Edm.String",
#       "key": true,
#       "retrievable": true,
#       "stored": true,
#       "searchable": false,
#       "filterable": true,
#       "sortable": false,
#       "facetable": true,
#       "synonym_maps": []
#     },
#     {
#       "name": "HotelName",
#       "type": "Edm.String",
#       "key": false,
#       "retrievable": true,
#       "stored": true,
#       "searchable": true,
#       "filterable": false,
#       "sortable": false,
#       "facetable": false,
#       "analyzer": "en.microsoft",
#       "synonym_maps": []
#     },
#     {
#       "name": "Description",
#       "type": "Edm.String",
#       "key": false,
#       "retrievable": true,
#       "stored": true,
#       "searchable": true,
#       "filterable": false,
#       "sortable": false,
#       "facetable": false,
#       "analyzer": "en.microsoft",
#       "synonym_maps": []
#     },
#     {
#       "name": "Description_fr",
#       "type": "Edm.String",
#       "key": false,
#       "retrievable": true,
#       "stored": true,
#       "searchable": true,
#       "filterable": false,
#       "sortable": false,
#       "facetable": false,
#       "analyzer": "fr.microsoft",
#       "synonym_maps": []
#     },
#     {
#       "name": "Category",
#       "type": "Edm.String",
#       "key": false,
#       "retrievable": true,
#       "stored": true,
#       "searchable": true,
#       "filterable": true,
#       "sortable": false,
#       "facetable": true,
#       "analyzer": "en.microsoft",
#       "synonym_maps": []
#     },
#     {
#       "name": "Tags",
#       "type": "Collection(Edm.String)",
#       "key": false,
#       "retrievable": true,
#       "stored": true,
#       "searchable": true,
#       "filterable": true,
#       "sortable": false,
#       "facetable": true,
#       "analyzer": "en.microsoft",
#       "synonym_maps": []
#     },
#     {
#       "name": "ParkingIncluded",
#       "type": "Edm.Boolean",
#       "key": false,
#       "retrievable": true,
#       "stored": true,
#       "searchable": false,
#       "filterable": true,
#       "sortable": false,
#       "facetable": true,
#       "synonym_maps": []
#     },
#     {
#       "name": "LastRenovationDate",
#       "type": "Edm.DateTimeOffset",
#       "key": false,
#       "retrievable": true,
#       "stored": true,
#       "searchable": false,
#       "filterable": false,
#       "sortable": true,
#       "facetable": false,
#       "synonym_maps": []
#     },
#     {
#       "name": "Rating",
#       "type": "Edm.Double",
#       "key": false,
#       "retrievable": true,
#       "stored": true,
#       "searchable": false,
#       "filterable": true,
#       "sortable": true,
#       "facetable": true,
#       "synonym_maps": []
#     },
#     {
#       "name": "Address",
#       "type": "Edm.ComplexType",
#       "fields": [
#         {
#           "name": "StreetAddress",
#           "type": "Edm.String",
#           "key": false,
#           "retrievable": true,
#           "stored": true,
#           "searchable": true,
#           "filterable": false,
#           "sortable": false,
#           "facetable": false,
#           "analyzer": "en.microsoft",
#           "synonym_maps": []
#         },
#         {
#           "name": "City",
#           "type": "Edm.String",
#           "key": false,
#           "retrievable": true,
#           "stored": true,
#           "searchable": true,
#           "filterable": true,
#           "sortable": false,
#           "facetable": true,
#           "analyzer": "en.microsoft",
#           "synonym_maps": []
#         },
#         {
#           "name": "StateProvince",
#           "type": "Edm.String",
#           "key": false,
#           "retrievable": true,
#           "stored": true,
#           "searchable": true,
#           "filterable": true,
#           "sortable": false,
#           "facetable": true,
#           "analyzer": "en.microsoft",
#           "synonym_maps": []
#         },
#         {
#           "name": "PostalCode",
#           "type": "Edm.String",
#           "key": false,
#           "retrievable": true,
#           "stored": true,
#           "searchable": true,
#           "filterable": true,
#           "sortable": false,
#           "facetable": true,
#           "analyzer": "en.microsoft",
#           "synonym_maps": []
#         },
#         {
#           "name": "Country",
#           "type": "Edm.String",
#           "key": false,
#           "retrievable": true,
#           "stored": true,
#           "searchable": true,
#           "filterable": true,
#           "sortable": false,
#           "facetable": true,
#           "analyzer": "en.microsoft",
#           "synonym_maps": []
#         }
#       ]
#     },
#     {
#       "name": "Location",
#       "type": "Edm.GeographyPoint",
#       "key": false,
#       "retrievable": true,
#       "stored": true,
#       "searchable": false,
#       "filterable": true,
#       "sortable": true,
#       "facetable": false,
#       "synonym_maps": []
#     },
#     {
#       "name": "Rooms",
#       "type": "Collection(Edm.ComplexType)",
#       "fields": [
#         {
#           "name": "Description",
#           "type": "Edm.String",
#           "key": false,
#           "retrievable": true,
#           "stored": true,
#           "searchable": true,
#           "filterable": false,
#           "sortable": false,
#           "facetable": false,
#           "analyzer": "en.microsoft",
#           "synonym_maps": []
#         },
#         {
#           "name": "Description_fr",
#           "type": "Edm.String",
#           "key": false,
#           "retrievable": true,
#           "stored": true,
#           "searchable": true,
#           "filterable": false,
#           "sortable": false,
#           "facetable": false,
#           "analyzer": "fr.microsoft",
#           "synonym_maps": []
#         },
#         {
#           "name": "Type",
#           "type": "Edm.String",
#           "key": false,
#           "retrievable": true,
#           "stored": true,
#           "searchable": true,
#           "filterable": true,
#           "sortable": false,
#           "facetable": true,
#           "analyzer": "en.microsoft",
#           "synonym_maps": []
#         },
#         {
#           "name": "BaseRate",
#           "type": "Edm.Double",
#           "key": false,
#           "retrievable": true,
#           "stored": true,
#           "searchable": false,
#           "filterable": true,
#           "sortable": false,
#           "facetable": true,
#           "synonym_maps": []
#         },
#         {
#           "name": "BedOptions",
#           "type": "Edm.String",
#           "key": false,
#           "retrievable": true,
#           "stored": true,
#           "searchable": true,
#           "filterable": true,
#           "sortable": false,
#           "facetable": true,
#           "analyzer": "en.microsoft",
#           "synonym_maps": []
#         },
#         {
#           "name": "SleepsCount",
#           "type": "Edm.Int64",
#           "key": false,
#           "retrievable": true,
#           "stored": true,
#           "searchable": false,
#           "filterable": true,
#           "sortable": false,
#           "facetable": true,
#           "synonym_maps": []
#         },
#         {
#           "name": "SmokingAllowed",
#           "type": "Edm.Boolean",
#           "key": false,
#           "retrievable": true,
#           "stored": true,
#           "searchable": false,
#           "filterable": true,
#           "sortable": false,
#           "facetable": true,
#           "synonym_maps": []
#         },
#         {
#           "name": "Tags",
#           "type": "Collection(Edm.String)",
#           "key": false,
#           "retrievable": true,
#           "stored": true,
#           "searchable": true,
#           "filterable": true,
#           "sortable": false,
#           "facetable": true,
#           "analyzer": "en.microsoft",
#           "synonym_maps": []
#         }
#       ]
#     },
#     {
#       "name": "id",
#       "type": "Edm.String",
#       "key": false,
#       "retrievable": false,
#       "stored": true,
#       "searchable": false,
#       "filterable": false,
#       "sortable": false,
#       "facetable": false,
#       "synonym_maps": []
#     },
#     {
#       "name": "rid",
#       "type": "Edm.String",
#       "key": false,
#       "retrievable": false,
#       "stored": true,
#       "searchable": false,
#       "filterable": false,
#       "sortable": false,
#       "facetable": false,
#       "synonym_maps": []
#     }
#   ],
#   "scoring_profiles": [],
#   "suggesters": [
#     {
#       "name": "sg",
#       "search_mode": "analyzingInfixMatching",
#       "source_fields": [
#         "Address/City",
#         "Address/Country",
#         "Rooms/Type",
#         "Rooms/Tags"
#       ]
#     }
#   ],
#   "token_filters": [],
#   "char_filters": [],
#   "normalizers": [],
#   "similarity": {
#     "odata_type": "#Microsoft.Azure.Search.BM25Similarity"
#   },
#   "e_tag": "\"0x8DDD70B74800468\""
# }
