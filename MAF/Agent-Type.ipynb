# %% [markdown]
# # 🤖 Microsoft Agent Framework 에이전트 유형
#
# ## 📋 개요
#
# Microsoft 에이전트 프레임워크는 다양한 사용 사례 및 요구 사항을 충족하기 위해 **여러 유형의 에이전트**를 지원합니다.
#
# 모든 에이전트는 공통 기본 클래스인 `AIAgent`에서 파생되며, 이는 모든 에이전트 유형에 **일관된 인터페이스**를 제공합니다. 이를 통해 에이전트에 공통 기능, 에이전트 중립적인 기능 뿐만 아니라 **다중 에이전트 오케스트레이션**과 같은 상위 수준 기능도 구축할 수 있습니다.
#
# > **⚠️ 중요 사항**
# >
# > Microsoft Agent Framework를 사용하여 타사 서버 또는 에이전트와 연동되는 애플리케이션을 구축하는 경우, 그에 따른 **위험은 전적으로 사용자에게 있습니다**. 타사 서버 또는 에이전트와 공유하는 모든 데이터를 검토하고, 타사의 데이터 보존 및 위치 정책을 숙지하는 것이 좋습니다. 데이터가 조직의 Azure 규정 준수 및 지리적 경계를 벗어나 유출될 경우, 그로 인해 발생할 수 있는 모든 영향에 대한 책임은 사용자에게 있습니다.

# %% [markdown]
# # 🚀 기본: 추론(inference) 서비스 기반의 에이전트
#
# Agent Framework를 사용하면 다양한 **추론 서비스를 기반**으로 하여 간단한 에이전트를 쉽게 만들 수 있습니다. 채팅 클라이언트 구현체를 제공하는 모든 추론 서비스를 사용하여 이러한 에이전트를 구축할 수 있습니다.
#
# > **📝 참고**
# >
# > 이어지는 실습에서는 주로 `AzureOpenAIChatClient` 구현체를 사용합니다만, 원한다면 `AzureAIAgentClient` 등 다른 채팅 클라이언트 구현체를 사용할 수 있습니다.
# >
# > 다음은 현재 지원되는 에이전트 유형들의 일부 목록을 보여줍니다. 이 외에도 다양한 에이전트 유형이 계속 추가되고 있으므로, 최신 정보는 [📚 공식 사이트의 문서](https://learn.microsoft.com/en-us/agent-framework/user-guide/agents/agent-types/?pivots=programming-language-python)를 참고하시기 바랍니다.
#
# ---
#
# ## 🎯 지원되는 에이전트 유형
#
# | 기본 추론 서비스 | 설명 | 서비스 채팅 기록 저장소 지원 | 사용자 지정 채팅 기록 저장소 지원 |
# |---------------|-----|:---:|:---:|
# | **Azure AI Agent** 🔷 | 백엔드로 Azure AI Agents Service를 사용하는 에이전트 | ✅ | ❌ |
# | **Azure OpenAI Chat Completion** 💬 | Azure OpenAI Chat Completion 서비스를 사용하는 에이전트 | ❌ | ✅ |
# | **Azure OpenAI Responses** 📨 | Azure OpenAI Responses 서비스를 사용하는 에이전트 | ✅ | ✅ |
# | **OpenAI Chat Completion** 🤖 | OpenAI Chat Completion 서비스를 사용하는 에이전트 | ❌ | ✅ |
# | **OpenAI Responses** 💡 | OpenAI Responses 서비스를 사용하는 에이전트 | ✅ | ✅ |
# | **OpenAI Assistants** 🎓 | OpenAI Assistants 서비스를 사용하는 에이전트 | ✅ | ❌ |
#
# ---
#
# ## ✨ 기본 지원 기능
#
# 이러한 에이전트는 다음과 같은 다양한 기능을 기본적으로 지원합니다:
#
# | 기능 | 설명 |
# |------|------|
# |🔧 **함수 호출** | Function calling 지원 |
# |💬 **다중-턴 대화** | 로컬 채팅 기록 또는 서비스 제공 채팅 기록 관리 |
# |🛠️ **사용자 지정 도구** | MCP, 코드 실행 등 서비스 제공 도구 |
# |📊 **구조화된 출력** | Structured output 지원 |
# |📡 **스트리밍 응답** | 실시간 응답 스트리밍 |
#
# ---
#
# ## 🏗️ 에이전트 생성 방법
#
# 이러한 에이전트를 생성하려면, 원하는 채팅 클라이언트의 구현체를 사용하여 `ChatAgent`를 구성하면 됩니다.

# %%
from agent_framework import ChatAgent
from agent_framework.azure import AzureAIAgentClient
from azure.identity.aio import DefaultAzureCredential

async with (
    DefaultAzureCredential() as credential,
    ChatAgent(
        chat_client=AzureAIAgentClient(credential=credential),
        instructions="당신은 한국어로 답변하는, 도움이 되는 어시스턴트입니다. 🤖✨"
    ) as agent
):
    response = await agent.run("좋은 아침입니다!")
    print(response)
# Out:
# 좋은 아침이에요!
# 오늘도 기분 좋게 하루 시작하시길 바랍니다.
# 혹시 도움이 필요한 일이 있으신가요? 😊

# %% [markdown]
# 혹은, 다음과 같이 채팅 클라이언트 구현체에서 제공하는 **간편한 메서드, as_agent()** 를 사용할 수도 있습니다. 🎯

# %%
from agent_framework.azure import AzureAIAgentClient
from azure.identity.aio import DefaultAzureCredential

async with DefaultAzureCredential() as credential:
    agent = AzureAIAgentClient(credential=credential).as_agent(
        instructions="당신은 한국어로 답변하는, 도움이 되는 어시스턴트입니다. 🤖✨"
    )

    response = await agent.run("오늘도 힘내세요!")
    print(response)
# Out:
# 고맙습니다!
# 당신도 오늘 힘내시고, 좋은 하루 보내세요!
# 혹시 도움이 필요하거나 나누고 싶은 이야기가 있다면 언제든 말씀해 주세요. 😊

# %% [markdown]
# ## 🔧 함수 도구 (Function Tools)
#
# 함수 도구를 사용하여 에이전트에 **향상된 기능**을 제공할 수 있습니다. 자세한 실습은 이어지는 과정에서 다룹니다.

# %%
from typing import Annotated
from pydantic import Field
from azure.identity.aio import DefaultAzureCredential
from agent_framework.azure import AzureAIAgentClient

def get_weather(location: Annotated[str, Field(description="날씨 정보를 가져올 위치입니다. 📍")]) -> str:
    """지정된 위치의 날씨 정보를 가져옵니다"""
    return f"{location}은 현재 맑으며, 최고 기온은 25°C 입니다."

async with (
    DefaultAzureCredential() as credential,
    AzureAIAgentClient(credential=credential).as_agent(
        instructions="당신은 한국어로 답변하는, 도움이 되는 날씨 어시스턴트입니다. ☀️☁️",
        tools=get_weather
    ) as agent
):
    response = await agent.run("시애틀의 날씨는 어떻습니까?")
    print(response.text)
# Out:
# Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x0000018B898E7920>
# Unclosed connector
# connections: ['deque([(<aiohttp.client_proto.ResponseHandler object at 0x0000018B85DE2F90>, 1509335.843)])']
# connector: <aiohttp.connector.TCPConnector object at 0x0000018B898E77D0>
# 시애틀은 현재 맑고, 최고 기온은 25°C입니다. 오늘 날씨가 아주 좋네요!

# %% [markdown]
# ## 📡 응답 스트리밍 (Streaming Responses)
#
# 에이전트는 **일반적인 응답**과 **스트리밍 응답**을 모두 지원합니다.
#
# ### 💡 스트리밍의 장점
#
# 스트리밍 응답을 사용하면 에이전트가 생성하는 콘텐츠를 **점진적으로 수신**할 수 있어:
# - ⚡ 대기 시간을 줄이고
# - ✨ 사용자 경험을 향상시킬 수 있습니다
#
# 자세한 실습은 이어지는 과정에서 다룹니다.

# %%
from agent_framework.azure import AzureAIAgentClient
from azure.identity.aio import DefaultAzureCredential

async with DefaultAzureCredential() as credential:
    agent = AzureAIAgentClient(credential=credential).as_agent(
        instructions="당신은 한국어로 답변하는, 도움이 되는 날씨 어시스턴트입니다. ☀️☁️"
    )

    # Streaming response (get results as they are generated)
    async for chunk in agent.run_stream("가장 인기 있는 SUV 차량은 무엇인가요?"):
        if chunk.text:
            print(chunk.text, end="", flush=True)
# Out:
# 현재(2024년 기준) 가장 인기 있는 SUV 차량을 글로벌 및 한국 시장 기준으로 소개해 드리겠습니다.
#
# ### 글로벌 기준
#
# 1. **Toyota RAV4**
#    - 세계에서 가장 많이 판매되는 SUV 중 하나로, 내구성과 연비, 다양한 옵션으로 많은 인기를 끌고 있습니다.
#
# 2. **Honda CR-V**
#    - 합리적인 가격과 뛰어난 실내 공간, 연비 등으로 꾸준히 높은 판매 실적을 기록하고 있습니다.
#
# 3. **Hyundai Tucson**
#    - 디자인과 첨단 사양, 경제성으로 글로벌 시장에서 빠르게 성장 중인 모델입니다.
#
# 4. **Kia Sportage**
#    - 현대적인 디자인과 다양한 안전•편의사양, 경쟁력 있는 가격으로 세계적으로 인기가 높습니다.
#
# 5. **Volkswagen Tiguan**
#    - 유럽 시장에서 꾸준히 인기 있는 모델이며, 글로벌 판매 역시 상위권에 위치해 있습니다.
#
# ### 한국 시장 기준
#
# 1. **현대 싼타페(Hyundai Santa Fe)**
#    - 가족 단위의 SUV로 넓은 공간과 최신 사양, 국내에서 매우 높은 판매고를 올리고 있습니다.
#
# 2. **기아 쏘렌토(Kia Sorento)**
#    - 다양한 파워트레인, 고급스러운 디자인과 편의사양으로 인기 있는 중형 SUV입니다.
#
# 3. **현대 투싼(Hyundai Tucson)**
#    - 스포티한 디자인, 경제적인 연비로 꾸준히 인기를 누리는 모델입니다.
#
# 4. **기아 스포티지(Kia Sportage)**
#    - 디자인 혁신과 시장 맞춤형 사양으로 젊은 소비자들에게 인기가 많습니다.
#
# ---
#
# **국내외 모두 최근에는 친환경(하이브리드/전기) SUV 모델의 인기도 빠르게 상승**하고 있습니다.
#
# 구매 목적, 예산, 선호하는 브랜드에 따라 인기 모델은 조금씩 다를 수 있으니, 참고해 주세요!
# ...

# %% [markdown]
# ## 🐍 코드 인터프리터 도구 (Code Interpreter Tools)
#
# Azure AI 에이전트는 코드 인터프리터 도구를 **내부적으로 호스팅하며 지원**하기에 Python 코드를 실행할 수 있습니다.

# %%
from agent_framework import ChatAgent, HostedCodeInterpreterTool
from agent_framework.azure import AzureAIAgentClient, AzureOpenAIChatClient
from azure.identity import DefaultAzureCredential

credential = DefaultAzureCredential()
async with ChatAgent(
    chat_client=AzureAIAgentClient(credential=credential),
    instructions="당신은 한국어로 답변하는, Python 코드를 실행할 수 있는 어시스턴트입니다.",
    tools=HostedCodeInterpreterTool()
) as agent:

    response = await agent.run("Python을 사용하여 100의 팩토리얼을 계산하세요")
    print(response)

# %% [markdown]
# # 🌟 다양한 에이전트 유형
#
# MAF에는 다양한 유형의 에이전트가 지원됩니다:
#
# | 에이전트 유형 | 설명 |
# |--------------|------|
# |🔷 **Azure AI Foundry Agent** | Azure AI Foundry 기반 에이전트 |
# |💬 **Azure OpenAI Agent** | Azure OpenAI 기반 에이전트 |
# |🤖 **OpenAI Agent** | OpenAI 기반 에이전트 |
# |🧠 **Anthropic Agents** | Anthropic 기반 에이전트 |
# |🐙 **GitHub Copilot Agent** | GitHub Copilot 기반 에이전트 |

# %% [markdown]
# > **📚 자세한 정보**
# >
# > 공식 사이트의 [지원되는 에이전트 유형](https://learn.microsoft.com/en-us/agent-framework/user-guide/agents/agent-types) 문서를 참조하세요.

# %% [markdown]
# ## 🎨 사용자 지정 에이전트 (Custom Agents)
#
# 원한다면, 채팅 클라이언트를 단순히 래핑하는 것이 아닌 **완전한 사용자 지정 에이전트**를 만들 수도 있습니다.
#
# ### 🛠️ 구현 방법
#
# 에이전트 프레임워크는 다음을 제공합니다:
# - `AgentProtocol` 프로토콜
# - `BaseAgent` 기본 클래스
#
# 이를 구현/하위 클래스화하면 **에이전트의 동작과 기능을 완전히 제어**할 수 있습니다.
#
# 다음은 코드 예시입니다:

# %%
from typing import Any
from agent_framework import BaseAgent, AgentResponse, AgentResponseUpdate, AgentThread, ChatMessage
from collections.abc import AsyncIterable

class CustomAgent(BaseAgent):
    async def run(
        self,
        messages: str | ChatMessage | list[str] | list[ChatMessage] | None = None,
        *,
        thread: AgentThread | None = None,
        **kwargs: Any,
    ) -> AgentResponse:
        # Custom agent implementation
        pass

    def run_stream(
        self,
        messages: str | ChatMessage | list[str] | list[ChatMessage] | None = None,
        *,
        thread: AgentThread | None = None,
        **kwargs: Any,
    ) -> AsyncIterable[AgentResponseUpdate]:
        # Custom streaming implementation
        pass
